# %% [markdown]
# <a href="https://colab.research.google.com/github/BettKelvin-spec/CBR-2-/blob/main/first_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **My First ML Project**

# %% [markdown]
# ## **Load data**

# %%
import pandas as pd
df = pd.read_csv('CBR.csv')
df
# Out:
#      Specific gravity  Linear shrinkage value (%)  Liquid limit, WL (%)  \
# 0                2.72                         9.3                  54.3
# 1                2.76                         9.6                  55.0
# 2                2.69                         9.1                  53.6
# 3                2.72                         9.5                  54.2
# 4                2.66                         9.0                  53.1
# ..                ...                         ...                   ...
# 175              2.71                        10.6                  56.0
# 176              2.63                        10.3                  54.3
# 177              2.66                        10.4                  54.9
# 178              2.68                        10.4                  55.3
# 179              2.69                        10.6                  55.6
#
#      Plastic limit, WP (%)  Plasticity index, PI (%)  \
# ...

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## **Data separation as x and y**

# %%
y = df['Soaked California bearing ratio, CBRs (%)']
y
# Out:
# 0      17
# 1      17
# 2      18
# 3      17
# 4      18
#        ..
# 175    14
# 176    15
# 177    15
# 178    14
# 179    14
# Name: Soaked California bearing ratio, CBRs (%), Length: 180, dtype: int64

# %%
x = df.drop(['Soaked California bearing ratio, CBRs (%)','Unsoaked California bearing ratio, CBRu (%)'], axis=1)
x
# Out:
#      Specific gravity  Linear shrinkage value (%)  Liquid limit, WL (%)  \
# 0                2.72                         9.3                  54.3
# 1                2.76                         9.6                  55.0
# 2                2.69                         9.1                  53.6
# 3                2.72                         9.5                  54.2
# 4                2.66                         9.0                  53.1
# ..                ...                         ...                   ...
# 175              2.71                        10.6                  56.0
# 176              2.63                        10.3                  54.3
# 177              2.66                        10.4                  54.9
# 178              2.68                        10.4                  55.3
# 179              2.69                        10.6                  55.6
#
#      Plastic limit, WP (%)  Plasticity index, PI (%)  \
# ...

# %% [markdown]
# ## Data splitting

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)
x_train
# Out:
#      Specific gravity  Linear shrinkage value (%)  Liquid limit, WL (%)  \
# 164              2.59                         9.7                  54.1
# 120              2.68                         9.3                  46.3
# 95               2.70                         9.2                  48.1
# 165              2.64                         9.9                  55.2
# 29               2.71                         9.2                  50.7
# ..                ...                         ...                   ...
# 87               2.62                         8.3                  41.1
# 103              2.66                        10.2                  51.2
# 67               2.59                         8.3                  41.2
# 24               2.67                         9.0                  50.1
# 8                2.68                         9.0                  53.5
#
#      Plastic limit, WP (%)  Plasticity index, PI (%)  \
# ...

# %%
x_test
# Out:
#      Specific gravity  Linear shrinkage value (%)  Liquid limit, WL (%)  \
# 88               2.64                         8.3                  41.5
# 145              2.67                         8.5                  42.9
# 11               2.72                         8.8                  48.6
# 74               2.60                         7.6                  37.6
# 173              2.71                        10.9                  56.1
# 150              2.67                        10.0                  52.3
# 151              2.70                        10.3                  53.0
# 97               2.65                         9.0                  47.2
# 90               2.71                         9.3                  48.3
# 96               2.62                         8.8                  46.6
# 147              2.62                         8.3                  42.0
# 65               2.64                         8.5                  42.1
# ...

# %% [markdown]
# # **Model Building**

# %% [markdown]
# ## **Linear regression**

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train, y_train)
LinearRegression()
# Out:
# LinearRegression()

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred = lr.predict(x_test)

# %%
print(y_lr_train_pred,)
# Out:
# [15.46444173 20.16370158 20.14111173 14.53560184 20.00616574 18.63982038
#  14.47339126 14.75696758 25.15095755 19.94840619 15.88127871 15.79242032
#  19.63085624 24.17697914 20.33650242 11.31640837 26.43102039 19.78677671
#  18.92551332 21.16064506 21.79923524 22.3544204  16.2484635  21.39693775
#  22.1989534  15.53094295 25.22533114 20.21074511 20.81292999 15.47051331
#  19.40760874 18.63064669 23.87059175 22.19483195 23.99302034 18.69835087
#  19.66880811 19.61233315 18.54589907 16.75696313 16.68645162 19.03268973
#  23.00491705 21.98724679 19.6799325  21.88251226 20.09683045 16.12730447
#  19.88254877 19.66561768 15.95285966 19.96752928 18.48511541 14.66304158
#  24.48484129 21.16901828 18.80478089 25.06668526 14.43106919 17.45247719
#  21.440996   23.18974257 18.25390618 23.28348886 24.79860426 19.49845787
#  25.06032519 21.24906337 13.58953182 14.5893224  20.97892769 14.56733044
#  21.83742242 15.56994742 23.86028212 17.43759975 19.9546018  24.31831617
# ...

# %%
y_lr_test_pred
# Out:
# array([21.44938056, 20.41781956, 20.81120335, 24.20479419, 13.96303429,
#        18.3408039 , 18.06499557, 21.21573942, 20.09192052, 20.56852419,
#        20.55391005, 20.38841354, 21.75918645, 14.75247272, 19.36348164,
#        20.13892824, 21.60112973, 17.64810015, 22.34873711, 25.11338949,
#        16.56006529, 23.38356805, 16.06771979, 21.13779329, 24.8889041 ,
#        18.04068175, 22.39288184, 15.99366912, 21.41290597, 13.4822276 ,
#        21.97412886, 20.4423378 , 20.00735523, 15.13988741, 15.96277056,
#        21.59213636])

# %% [markdown]
# ## **Evaluate model performance**

# %%
from sklearn.metrics import mean_squared_error, r2_score
lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)
lr_test_mse = mean_squared_error(y_test, y_lr_test_pred)

lr_train_r2 = r2_score(y_train, y_lr_train_pred)
lr_test_r2 = r2_score(y_test, y_lr_test_pred)

# %%
lr_results = pd.DataFrame(['Linear regression', lr_train_mse, lr_train_r2, lr_test_mse, lr_test_r2]).transpose()
lr_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
lr_results
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear regression     3.761166    0.707422  5.127109  0.670841

# %% [markdown]
# # **Random Forest**

# %% [markdown]
# ## Training the model

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(max_depth=2, random_state=100)
rf.fit(x_train, y_train)
RandomForestRegressor()
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## Applying the model to make a prediction

# %%
y_rf_train_pred = rf.predict(x_train)
y_rf_test_pred = rf.predict(x_test)

# %% [markdown]
# ## Evaluate model performance

# %%
from sklearn.metrics import mean_squared_error, r2_score
rf_train_mse = mean_squared_error(y_train, y_rf_train_pred)
rf_test_mse = mean_squared_error(y_test, y_rf_test_pred)

rf_train_r2 = r2_score(y_train, y_rf_train_pred)
rf_test_r2 = r2_score(y_test, y_rf_test_pred)

# %%
rf_results = pd.DataFrame(['Random Forest', rf_train_mse, rf_train_r2, rf_test_mse, rf_test_r2]).transpose()
rf_results.columns = ['Method', 'Training MSE', 'Training R2', 'Test MSE', 'Test R2']
rf_results
# Out:
#           Method Training MSE Training R2  Test MSE   Test R2
# 0  Random Forest     2.096737    0.836897  4.117903  0.735632

# %% [markdown]
# ## Model comparison

# %%
df_models = pd.concat([lr_results, rf_results], axis=0).reset_index()
df_models.drop(['index'], axis=1, inplace=True)
df_models
# Out:
#               Method Training MSE Training R2  Test MSE   Test R2
# 0  Linear regression     3.761166    0.707422  5.127109  0.670841
# 1      Random Forest     2.096737    0.836897  4.117903  0.735632

# %% [markdown]
# # **Data visualization**

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(5,5))
plt.scatter(x = y_train, y = y_lr_train_pred, c = "#7CAE00", alpha=0.3)

z = np.polyfit(y_train, y_lr_train_pred, 1)
p = np.poly1d(z)

plt.plot(y_train, p(y_train), '#F8766D')
plt.ylabel('Predicted CBR')
plt.xlabel('Actual CBR')
# Out:
# Text(0.5, 0, 'Actual CBR')

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7b7c4df4-416b-4e16-bd0b-b65e3013932a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7b7c4df4-416b-4e16-bd0b-b65e3013932a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
